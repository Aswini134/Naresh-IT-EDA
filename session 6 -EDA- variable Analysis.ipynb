# %% [markdown]
# $ categorical $ vs $Categorical$

# %%
import pandas as pd                  # dataframe operations
import numpy as np                   # math operations
import matplotlib.pyplot as plt      # diagrams/plots
import seaborn as sns                # diagrams / plots
path=r"C:\Users\vampa\OneDrive\Documents\nareshIT-DATASCIENCE\EDA\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
#continent 
#case_status
# as we know that there are 25480 observations are there
# in that 16k are from asia applications
# out of 16k applications how many visa approved/certified
# out of 16k applicants how many visa rejected/denied

# %%
c1=visa_df['continent']=="Asia"
c2=visa_df['case_status']=='Certified'
con=c1&c2
Certified_count=len(visa_df[con])
print(f"there are {Certified_count} got certified from Asia")
# Out:
# there are 11012 got certified from Asia

# %%
#one more
c1=visa_df['continent']=="Asia"
c2=visa_df['case_status']=='Certified'
c3=visa_df['case_status']=='Denied'
cer_con=c1&c2
den_con=c1&c3
Certified_count=len(visa_df[cer_con])
denied_count=len(visa_df[den_con])
print(f"there are {Certified_count} got certified from Asia")
print(f"there are {denied_count} got denied from Asia")
# Out:
# there are 11012 got certified from Asia
# there are 5849 got denied from Asia

# %%
c1=visa_df['continent']=="Asia"
c2=visa_df['case_status']=='Certified'
con=c1&c2
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
create dataframe certified and denied
      Denied    Certified
Asia   v1        v2
Europe v1        v2

# %%
#step 1: make unique labels
labels=visa_df['continent'].unique()
# step 2: create empty two lists
Certified_count=[]
denied_count=[]
# step 3: iterate through loop
for i in labels:
    c1=visa_df['continent']==i
    c2=visa_df['case_status']=='Certified'
    c3=visa_df['case_status']=='Denied'
    cer_con=c1&c2
    den_con=c1&c3
    Certified_count.append(len(visa_df[cer_con]))
    denied_count.append(len(visa_df[den_con]))
    cols=['continent','Certified','Denied']
d1=pd.DataFrame(zip(labels,Certified_count,denied_count),columns=cols)
d1
# Out:
#        continent  Certified  Denied
# 0           Asia      11012    5849
# 1         Africa        397     154
# 2  North America       2037    1255
# 3         Europe       2957     775
# 4  South America        493     359
# 5        Oceania        122      70

# %%
d1.set_index('continent')
# use set_index which column you want to set as index for ex: continent
# Out:
#                Certified  Denied
# continent
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %%
d1.set_index('Certified')
# use set_index which column you want to set as index for ex: Certified
# Out:
#                continent  Denied
# Certified
# 11012               Asia    5849
# 397               Africa     154
# 2037       North America    1255
# 2957              Europe     775
# 493        South America     359
# 122              Oceania      70

# %%
#step 1: make unique labels
labels=visa_df['continent'].unique()
# step 2: create empty two lists
Certified_count=[]
denied_count=[]
# step 3: iterate through loop
for i in labels:
    c1=visa_df['continent']==i
    c2=visa_df['case_status']=='Certified'
    c3=visa_df['case_status']=='Denied'
    cer_con=c1&c2
    den_con=c1&c3
    Certified_count.append(len(visa_df[cer_con]))
    denied_count.append(len(visa_df[den_con]))
    cols=['continent','Certified','Denied']
d1=pd.DataFrame(zip(labels,Certified_count,denied_count),columns=cols)
d1.set_index('continent')
# Out:
#                Certified  Denied
# continent
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %% [markdown]
# # pd.crosstab
# - will take two arguments
# - index
# - column

# %%
col1=visa_df['case_status']
col2=visa_df['continent']
result1=pd.crosstab(col2,col1)
result1
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
col1=[visa_df['continent'],visa_df['education_of_employee']]
col2=visa_df['case_status']
result2=pd.crosstab(col1,col2)
result2
# Out:
# case_status                          Certified  Denied
# continent     education_of_employee
# Africa        Bachelor's                    81      62
#               Doctorate                     43      11
#               High School                   23      43
#               Master's                     250      38
# Asia          Bachelor's                  4407    2761
#               Doctorate                    780     143
#               High School                  676    1614
#               Master's                    5149    1331
# Europe        Bachelor's                  1040     259
#               Doctorate                    788      58
#               High School                  162     328
#               Master's                     967     130
# North America Bachelor's                   641     584
#               Doctorate                    207      51
#               High School                  210     191
# ...

# %%
result1.plot(kind='bar')
plt.show()

# %%
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='continent,education_of_employee'>

# %%
col1=visa_df['continent']
col2=visa_df['education_of_employee']
col3=visa_df['case_status']
r2=pd.crosstab(col1,[col2,col3])
r2.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>
